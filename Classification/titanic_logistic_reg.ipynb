# %%
import numpy as np;
import pandas as pd
from sklearn import preprocessing
import matplotlib as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.shape[0]
# Out:
# 891

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Plotting a basic histogram
plt.hist(train_df['Age'], bins=80, color='teal', edgecolor='black')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Train_DF Age')

# Display the plot
plt.show()

# %% [markdown]
# The distribution's tail indicates skewness. So if the tail faces right, its right skewed, just like above.
# Or, a histogram skewed to the right means that the peak of the graph lies to the left side of the center.
# Properties of a Right Skewed Graph:
# 1. Mean >= Median >= Mode

# %%
train_df['Age'].mean()
# Out:
# 29.69911764705882

# %%
train_df['Age'].median()
# Out:
# 28.0

# %%
train_df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
train_df['Age'].fillna(train_df['Age'].mean(), inplace=True)
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df['Cabin'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 train_df['Cabin'].sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:6519, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6510 @doc(make_doc("sum", ndim=1))
#    6511 def sum(
#    6512     self,
#    (...)
#    6517     **kwargs,
#    6518 ):
# -> 6519     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:12503, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12495 def sum(
#   12496     self,
#   12497     axis: Axis | None = 0,
#    (...)
#   12501     **kwargs,
#   12502 ):
# > 12503     return self._min_count_stat_function(
# ...
